# %%
# Read a whole file 

with open('atm_customers.csv' , 'r') as file :
    data = file.read()
    print(data)
# Out:
# Name,Account Number,PIN,Balance
# Grace Yellow,45042,5185,69553
# Jane Smith,85965,3190,64865
# Alice Johnson,48360,1610,21162
# Grace Yellow,80624,9324,70408
# Alice Johnson,53525,8201,28238
# Eva Green,93363,2272,36763
# Bob Brown,78260,2282,69659
# Kiriti Aajad,54994,3248,88276
# David Black,23377,6128,48362
# Charlie White,92877,8001,14016
# Grace Yellow,31014,6196,39200
# Kiriti Aajad,88291,4285,79793
# Bob Brown,13607,1788,55036
# John Doe,40965,1427,47134
# Eva Green,88477,7582,86401
# Frank Blue,24932,9398,20668
# Eva Green,71237,3059,93004
# Bob Brown,27412,3316,70637
# David Black,86470,7754,11091
# John Doe,77375,6653,46259
# Jane Smith,82146,4093,57833
# David Black,85815,6839,43726
# Alice Johnson,48136,4187,9618
# Jane Smith,90868,3159,70573
# Eva Green,61700,2545,89517
# Charlie White,62821,7122,96490
# Alice Johnson,70966,1595,99937
# Alice Johnson,83182,1832,53962
# Frank Blue,13778,2918,98769
# Bob Brown,18206,4818,32775
# Eva Green,75763,8339,15994
# ...

# %%
# Write in file 
with open('atm_customers1.csv' , 'w') as file:
    data = ['Kiriti Aajad Rajdheer',61019,2168,40766]
    file.write(','.join(map(str, data)))  # Write data to file
